# %% [markdown]
# # Results overview
#
# Notebooks `01`–`09` read `results/`, `mlflow.db`, and checkpoint PNGs.
#
# Exports:
# - figures → `plots/results/`
# - numeric tables → `report_snippets/` (`.tex`, `.csv`, `.json` only — no prose)

# %%
from pathlib import Path

SNIPPETS = Path("report_snippets")
PLOTS = Path("plots/results")
print("=== report_snippets ===")
for path in sorted(SNIPPETS.iterdir()):
    print(path.name, path.stat().st_size, "bytes")
print("\n=== plots/results ===")
for path in sorted(PLOTS.glob("*.png")):
    print(path.name)
# Out:
# === report_snippets ===
# checkpoint_coverage.csv 137 bytes
# chimera_runs.csv 474 bytes
# fid_all_evals.csv 3789 bytes
# fid_best_runs.csv 287 bytes
# fid_mlflow_join.csv 9555 bytes
# fid_table.tex 674 bytes
# interpolation_index.json 198 bytes
# mlflow_summary.csv 629 bytes
# mlflow_summary.tex 574 bytes
# mlflow_training_timing.tex 643 bytes
# prior_timing.csv 865 bytes
# prior_timing.tex 309 bytes
# progression_runs.csv 317 bytes
# qualitative_assets.csv 1088 bytes
# training_curve_runs.csv 1044 bytes
#
# === plots/results ===
# chimera_panel.png
# chimera_progress_chimera_64_seed0.png
# chimera_progress_chimera_64_seed3407.png
# chimera_progress_chimera_64_seed42.png
# fid_best_runs.png
# fid_grid_distribution.png
# fid_vs_best_metric.png
# interpolation_beta_vae_seed3407.png
# interpolation_panel.png
# interpolation_wgan_gp_seed3407.png
# mlflow_run_summary.png
# prior_samples_panel.png
# prior_timing.png
# progression_all_best_fid.png
# progression_beta_vae_best_fid.png
# ...
